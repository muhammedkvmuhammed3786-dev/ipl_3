# %%
import sqlite3
import pandas as pd

con=sqlite3.connect(r'C:\Users\muham\OneDrive\Desktop\Proj_3.1\Data\Raw\ipl.db')
def q(sql):
    return pd.read_sql(sql, con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script =f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
q("""
    -- what is the strike rate of every batter in the death overs

    select batter,round(100.0*sum(batter_runs)/sum(
      CASE
        when is_wide_ball=0 AND is_no_ball=0
        then 1
        else 0
      END ),2)as strike_rate

from deliveries
where over_number>=15 AND is_super_over=0
group by batter
order by strike_rate desc;
    """)
# Out:
#              batter  strike_rate
# 0          WG Jacks       483.33
# 1          DT Patil       400.00
# 2        KT Maphaka       400.00
# 3            L Wood       300.00
# 4          PA Reddy       300.00
# ..              ...          ...
# 637     Sunny Gupta         0.00
# 638          U Kaul         0.00
# 639  V Pratap Singh         0.00
# 640   Y Prithvi Raj         0.00
# 641      YA Abdulla         0.00
#
# [642 rows x 2 columns]

# %%
run_sql_file(r'C:\Users\muham\OneDrive\Desktop\Proj_3.1\sql\09_analysis_views.sql')
# Out:
# ran C:\Users\muham\OneDrive\Desktop\Proj_3.1\sql\09_analysis_views.sql

# %%
q(""" select *
from v_ball;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288046       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288047       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288048       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288049       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288050       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""select phase, count(*) from v_ball group by phase;""")
# Out:
#        phase  count(*)
# 0      Death     65488
# 1     Middle    132173
# 2  Powerplay     90390

# %%
q("""select count(*) from v_match_totals;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\muham\miniconda3\envs\proj_2.1_venv\lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: v_match_totals
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 q("""select count(*) from v_match_totals;""")
#
# Cell In[14], line 6, in q(sql)
#       5 def q(sql):
# ----> 6     return pd.read_sql(sql, con)
#
# File c:\Users\muham\miniconda3\envs\proj_2.1_venv\lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
q("""select count(*) from v_innings;""")
# Out:
#    count(*)
# 0      2418

# %%
q(""" select phase, count(*) from v_ball;""")
# Out:
#        phase  count(*)
# 0  Powerplay    288051
